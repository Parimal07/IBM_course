# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  __Parimal Kolhe__ <br>
#  I am currently a B.Tech Student.

# %% [markdown]
#  _I want to become a data scientist as i love working with data._

# %% [markdown]
# ### Here is the code to check if a number is even or odd

# %%
a = int(input("Enter any number : "))
if(a % 2 == 0):
    print("Entered number is even number")
else:
    print("Entered number is odd number")
# Out:
# Enter any number :  4
# Entered number is even number

# %% [markdown]
# ### BULLET LIST

# %% [markdown]
# - Follwing are names of some fruits:
#     - APPLE
#     - MANGO
#     - PAPAYA

# %% [markdown]
# ### NUMBERED LIST

# %% [markdown]
# 1. Monday
# 2. Tuesday
# 3. Wednesday
# 4. Thursday
# 5. Friday
# 6. Saturday
# 6. Sunday

# %% [markdown]
# ### IMAGE

# %% [markdown]
# ![operating_system_user_interface_security_memory_Slide01.jpg](attachment:e63738a9-af27-4010-a921-71a83ed1fb04.jpg)
